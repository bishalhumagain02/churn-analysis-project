# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder , LabelEncoder , StandardScaler
from sklearn.pipeline import Pipeline
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\humag\OneDrive\Documents\PYTHON\churn-analysis-project\data\raw\Telco-Customer-Churn.csv')

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df['AVG_MONTLY_CHARGES'] = df['TotalCharges'] / df['tenure'].clip(lower=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\humag\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File c:\Users\humag\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\humag\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# ...

# %%
df.drop('customerID', axis=1, inplace=True)

# %%
categorical_columns = df.select_dtypes(include='object').columns.tolist()
print(categorical_columns)
# Out:
# ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges', 'Churn']

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
# Convert to numeric but keep track of invalids
invalid_mask = pd.to_numeric(df['TotalCharges'], errors='coerce').isna()

# Show rows where conversion failed
df.loc[invalid_mask, 'TotalCharges']
# Out:
# 488    NaN
# 753    NaN
# 936    NaN
# 1082   NaN
# 1340   NaN
# 3331   NaN
# 3826   NaN
# 4380   NaN
# 5218   NaN
# 6670   NaN
# 6754   NaN
# Name: TotalCharges, dtype: float64

# %%
df['TotalCharges'] = df['TotalCharges'].replace(' ', np.nan)

# %%
df.isnull().sum().sum()
df.dropna(inplace=True)
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df['TotalCharges'] = df['TotalCharges'].astype(float)
df['TotalCharges'].dtypes
# Out:
# dtype('float64')

# %%
df['TotalCharges'].describe()
# Out:
# count    7032.000000
# mean     2283.300441
# std      2266.771362
# min        18.800000
# 25%       401.450000
# 50%      1397.475000
# 75%      3794.737500
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %%
numeric_columns = df.select_dtypes(include=np.number).columns.tolist()
print(numeric_columns)
# Out:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges']

# %%
df.nunique()
# Out:
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                72
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1584
# TotalCharges        6530
# Churn                  2
# dtype: int64

# %%
df['total_revenue']=df['MonthlyCharges']/df['tenure']
print(df['total_revenue'].describe())
# Out:
# count    7032.000000
# mean        8.620087
# std        16.352057
# min         0.268056
# 25%         1.277708
# 50%         2.147286
# 75%         6.611218
# max       102.450000
# Name: total_revenue, dtype: float64
